# %%
import scipy.stats as stats
import statsmodels.api as sm
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from PIL import ImageGrab
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
from IPython import display

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-73e33043-00d8-45a9-9012-b16dd54f996a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-73e33043-00d8-45a9-9012-b16dd54f996a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# QUESTION 1

# %%
display.Image("Hypothesis Question 1.png")

# %% [markdown]
# We are going to conduct a 2 tailed T-Test on 2 Independent samples with Numerical Data

# %% [markdown]
# We need to check whether the mean of both samples are different and Is there any significance difference between the two samples?
# ---

# %% [markdown]
# STEP 1

# %% [markdown]
# Make two Hypothesis one contradicting to other Null Hypothesis is want we want to prove

# %% [markdown]
#  * Null Hypothesis
#  * Alternative Hypothesis

# %% [markdown]
# STEP 2

# %% [markdown]
# Decide a cut-off value

# %% [markdown]
#  * Significance = 5%
#  * Alpha = 0.05

# %% [markdown]
# As it is a two-tailed test
#   * Alpha/2 = 0.025

# %% [markdown]
# Step 3

# %% [markdown]
# Collect evidence

# %% [markdown]
# Importing Files

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-beeafa7b-12bf-4aed-8c2c-ade8b03529ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-beeafa7b-12bf-4aed-8c2c-ade8b03529ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cutlets = pd.read_csv("Cutlets.csv")

# %%
cutlets.head(10)
# Out:
#    Unit A  Unit B
# 0  6.8090  6.7703
# 1  6.4376  7.5093
# 2  6.9157  6.7300
# 3  7.3012  6.7878
# 4  7.4488  7.1522
# 5  7.3871  6.8110
# 6  6.8755  7.2212
# 7  7.0621  6.6606
# 8  6.6840  7.2402
# 9  6.8236  7.0503

# %% [markdown]
# Applying Descriptive Statistcis

# %%
cutlets.describe()
# Out:
#           Unit A     Unit B
# count  35.000000  35.000000
# mean    7.019091   6.964297
# std     0.288408   0.343401
# min     6.437600   6.038000
# 25%     6.831500   6.753600
# 50%     6.943800   6.939900
# 75%     7.280550   7.195000
# max     7.516900   7.545900

# %% [markdown]
# Checking for Null Values

# %%
cutlets.isnull().sum()
# Out:
# Unit A    0
# Unit B    0
# dtype: int64

# %% [markdown]
# Checking for Duplicate Values

# %%
cutlets[cutlets.duplicated()].shape
# Out:
# (0, 2)

# %%
cutlets[cutlets.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unit A, Unit B]
# Index: []

# %% [markdown]
# Checking the DataType

# %%
cutlets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Unit A  35 non-null     float64
#  1   Unit B  35 non-null     float64
# dtypes: float64(2)
# memory usage: 688.0 bytes

# %% [markdown]
# Plotting the Data

# %%
plt.subplots(figsize = (9,6))
plt.subplot(121)
plt.boxplot(cutlets['Unit A'])
plt.title("Unit A")
plt.subplot(122)
plt.boxplot(cutlets['Unit B'])
plt.title('Unit B')
plt.show()

# %%
plt.subplots(figsize = (9,6))
plt.subplot(121)
plt.hist(cutlets["Unit A"], bins = 15)
plt.title("Unit A")
plt.subplot(122)
plt.hist(cutlets["Unit B"], bins = 15)
plt.title("Unit B")
plt.show()

# %%
plt.figure(figsize = (8,6))
labels = ["Unit A", "Unit B"]
sns.distplot(cutlets["Unit A"], kde = True)
sns.distplot(cutlets["Unit B"], kde = True)
plt.legend(labels)

# %% [markdown]
# Plotting Q-Q plot to check whether the distribution follows normal distribution or not

# %%
sm.qqplot(cutlets["Unit A"], line = 'q')
plt.title("Unit A")
sm.qqplot(cutlets["Unit B"], line = 'q')
plt.title("Unit B")
plt.show()

# %% [markdown]
# Step 4

# %% [markdown]
# Compare Evidence with Hypothesis using T-statistics

# %%
statistic , p_value = stats.ttest_ind(cutlets["Unit A"], cutlets["Unit B"], alternative = 'two-sided')
print('p_value=', p_value)
# Out:
# p_value= 0.4722394724599501

# %% [markdown]
# Compare p_value with 'α' (Significane Level)

# %% [markdown]
# If p_value is ≠'α' we failed to reject Null Hypothesis because of lack of evidence.
#
# If p_value is = 'α' we reject Null Hypothesis

# %% [markdown]
# Interpreting p-value

# %%
alpha = 0.025
print("Significance = %.3f, p=%.3f" % (alpha, p_value))
if p_value <= alpha:
    print("We reject Null Hypothesis there is a significance difference between two units A and B")
else:
    print("We fail to reject Null Hypothesis")
# Out:
# Significance = 0.025, p=0.472
# We fail to reject Null Hypothesis

# %% [markdown]
# Hence, We fail to reject Null Hypothesis because of lack of evidence, there is no significant diffence between the two samples

# %% [markdown]
# QUESTION 2

# %%
from google.colab import files
from IPython import display

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b9456f27-b330-4c93-99a2-8799d28b1b97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9456f27-b330-4c93-99a2-8799d28b1b97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
display.Image("Hypothesis Question 2.png")

# %% [markdown]
#    We are going to conduct a ANOVA TEST on 4 Independent samples with Numerical Data
#
#  We need to check whether the mean any of these samples are different or the same?

# %% [markdown]
# > STEP 1

# %% [markdown]
# Make two Hypothesis one contradicting to other
#
# Null Hypothesis is want we want to prove

# %% [markdown]
# *   Null Hypothesis: μ1=μ2  = μ3 = μ4
# *   Alternative Hypothesis: Atleast One of them is Different

# %% [markdown]
# STEP 2
#
# > Decide a cut-off value
#
#
#
# *   Significance 5%
# *   alpha = 0.05

# %% [markdown]
# STEP 3
#
# Collect Evidence

# %% [markdown]
# Importing Files

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3938a6c1-84d7-4aa8-b0a2-15f6e3bb6d2d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3938a6c1-84d7-4aa8-b0a2-15f6e3bb6d2d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
labtat = pd.read_csv("LabTAT.csv")
labtat.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %% [markdown]
# Applying Descriptive Statistics

# %%
labtat.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %% [markdown]
# Checking for Null Values

# %%
labtat.isnull().sum()
# Out:
# Laboratory 1    0
# Laboratory 2    0
# Laboratory 3    0
# Laboratory 4    0
# dtype: int64

# %% [markdown]
# Checking for Duplicate Values

# %%
labtat[labtat.duplicated()].shape
# Out:
# (0, 4)

# %%
labtat[labtat.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Laboratory 1, Laboratory 2, Laboratory 3, Laboratory 4]
# Index: []

# %% [markdown]
# Checking the Data Type

# %%
labtat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laboratory 1  120 non-null    float64
#  1   Laboratory 2  120 non-null    float64
#  2   Laboratory 3  120 non-null    float64
#  3   Laboratory 4  120 non-null    float64
# dtypes: float64(4)
# memory usage: 3.9 KB

# %% [markdown]
# Plotting the Data

# %%
plt.subplots(figsize = (16,9))
plt.subplot(221)
plt.boxplot(labtat['Laboratory 1'])
plt.title('Laboratory 1')
plt.subplot(222)
plt.boxplot(labtat['Laboratory 2'])
plt.title('Laboratory 2')
plt.subplot(223)
plt.boxplot(labtat['Laboratory 3'])
plt.title('Laboratory 3')
plt.subplot(224)
plt.boxplot(labtat['Laboratory 4'])
plt.title('Laboratory 4')
plt.show()

# %%
plt.subplots(figsize = (9,6))
plt.subplot(221)
plt.hist(labtat['Laboratory 1'])
plt.title('Laboratory 1')
plt.subplot(222)
plt.hist(labtat['Laboratory 2'])
plt.title('Laboratory 2')
plt.subplot(223)
plt.hist(labtat['Laboratory 3'])
plt.title('Laboratory 3')
plt.subplot(224)
plt.hist(labtat['Laboratory 4'])
plt.title('Laboratory 4')
plt.show()

# %%
plt.figure(figsize = (8,6))
labels = ['Lab 1', 'Lab 2', 'Lab 3', 'Lab 4']
sns.distplot(labtat['Laboratory 1'], kde = True)
sns.distplot(labtat['Laboratory 2'], hist = True)
sns.distplot(labtat['Laboratory 3'], hist = True)
sns.distplot(labtat['Laboratory 4'], hist = True)
plt.legend(labels)

# %% [markdown]
# Ploting Q-Q plot to check whether the distribution follows normal distribution or not

# %%
sm.qqplot(labtat['Laboratory 1'], line = 'q')
plt.title('Laboratory 1')
sm.qqplot(labtat['Laboratory 2'], line = 'q')
plt.title('Laboratory 2')
sm.qqplot(labtat['Laboratory 3'], line = 'q')
plt.title('Laboratory 3')
sm.qqplot(labtat['Laboratory 4'], line = 'q')
plt.title('Laboratory 4')
plt.show()

# %% [markdown]
# STEP 4
#
#
# > Compare Evidence with Hypothesis using t-statistics

# %%
test_statistic , p_value = stats.f_oneway(labtat.iloc[:,0], labtat.iloc[:,2], labtat.iloc[:,3])
print('p_value =',p_value)
# Out:
# p_value = 3.516514500116922e-54

# %% [markdown]
# Compare p_value with 'α' (Significant Level)
#
#
#
# *   If p_value is ≠ 'α' we failed to
#  reject Null Hypothesis because of lack of evidence.
# *   If p_value is = 'α' we reject Null Hypothesis.

# %% [markdown]
# Interpreting p-value

# %%
alpha = 0.05
print("Significance =%.3f, p=%.3f" % (alpha, p_value))
if p_value <= alpha:
  print("We reject Null Hypothesis there is a significance difference between TAT of reports of the laboratories")
else:
  print("We fail to reject Null Hypothesis")
# Out:
# Significance =0.050, p=0.000
# We reject Null Hypothesis there is a significance difference between TAT of reports of the laboratories

# %% [markdown]
# ANSWER
#
# Hence, We fail to reject Null Hypothesis because of lack of evidence, there is no significant difference between the samples.

# %% [markdown]
# QUESTION 3

# %%
from google.colab import files
from IPython import display

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-40e8fe9b-9d4c-4093-b473-dc9511ac99c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40e8fe9b-9d4c-4093-b473-dc9511ac99c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
display.Image("Hypothesis Question 3.png")

# %% [markdown]
# We are going to conduct a Test of Independence using Chi-Square χ2 test with Contingency Table.
#
#
# We need to check whether the proportion of any of these samples are different or the same?

# %% [markdown]
# STEP 1
#
# Make two Hypothesis one contradicting to other.
# Null Hypothesis is want we want to prove.
#
#
#
# * **Null Hypothesis**:There is no association or dependency between the gender based buyer rations across regions.
#
# *   **Alternative Hypothesis**:There is a significant association or dependency between the gender based buyer rations across regions.

# %% [markdown]
# STEP 2
#
# Decide a cut-off value
#
#
# *   Significance 5%
# *   alpha = 0.05
#
# As it is a one-tailed test
#
#
# *  alpha = 1-0.95 =0.05

# %% [markdown]
# STEP 3
#
# Collect Evidence

# %% [markdown]
# Importing files

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f46b21bf-a736-4e18-84ee-ebf1d5826495" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f46b21bf-a736-4e18-84ee-ebf1d5826495">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
buyer = pd.read_csv("BuyerRatio.csv", index_col = 0)
buyer
# Out:
#                  East  West  North  South
# Observed Values
# Males              50   142    131     70
# Females           435  1523   1356    750

# %%
table =[[50,142,131,70],
        [435,1523,1356,750]]

# %% [markdown]
# Applying Chi-Square χ2 contingency table to convert observed value into expected value

# %%
stat, p, dof, exp = stats.chi2_contingency(buyer)
print(stat, "\n", p, "\n", dof, "\n", exp)
# Out:
# 1.595945538661058
#  0.6603094907091882
#  3
#  [[  42.76531299  146.81287862  131.11756787   72.30424052]
#  [ 442.23468701 1518.18712138 1355.88243213  747.69575948]]

# %%
stats.chi2_contingency(table)
# Out:
# Chi2ContingencyResult(statistic=1.595945538661058, pvalue=0.6603094907091882, dof=3, expected_freq=array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]]))

# %%
observed = np.array([50, 142, 131, 70, 435, 1523, 1356, 750])
expected = np.array([42.76531299, 146.81287862, 131.11756787, 72.30424052, 442.23468701, 1518.18712138, 1355.88243213, 747.69575948])

# %% [markdown]
# STEP 4
#
# Comparing Evidence with Hypothesis

# %%
statistics, p_value = stats.chisquare(observed, expected, ddof = 3)
print("Statistics = ", statistics, "\n", 'P_value = ', p_value)
# Out:
# Statistics =  1.5959455390914483
#  P_value =  0.8095206646905712

# %% [markdown]
# Compare p_value with 'α'(Significane Level)

# %% [markdown]
# If p_value is ≠ 'α' we failed to reject Null Hypothesis because of lack of evidence.
#
# If p_value is = 'α' we reject Null Hypothesis.

# %% [markdown]
# Interpreting p-value

# %%
alpha = 0.05
print('Significance = %.3f, p=%.3f' % (alpha, p_value))
if p_value <= alpha:
  print("We reject Null Hypothesis there is a significance difference between TAT of reports of the Laboratories")
else:
  print("We fail to reject Null Hypothesis")
# Out:
# Significance = 0.050, p=0.810
# We fail to reject Null Hypothesis

# %% [markdown]
# ANSWER:
#   We fail to reject NULL HYPOTHESIS because of lack evidence.
#   Therefore, there is no association or dependency between male-famale buyers rations and are similar across regions.
#   Hence, Independent samples.

# %% [markdown]
# QUESTION 4

# %%
from google.colab import files
from IPython import display
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b1320bf6-3a46-4baf-b320-e13195678fce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1320bf6-3a46-4baf-b320-e13195678fce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
display.Image("Hypothesis Question 4.png")

# %% [markdown]
# We are going to conduct a Test of Independence using Chi-Square  χ2  test with Contingency table
#
#
#
# ---
# We need to check whether the mean of any of these samples are different or the same?

# %% [markdown]
# STEP 1
#
# Make two Hypothesis one contradicting to other
#
# Null Hypothesis is want we want to prove

# %% [markdown]
# * Null Hypothesis:  μ1=μ2  =  μ3  =  μ4
#
# * Alternative Hypthosis: Atleast One of them is Differente

# %% [markdown]
# STEP 2
#
# Decide a cut-off value

# %% [markdown]
# * Significance 5%
# * alpha = 0.05

# %% [markdown]
# STEP 3
#
# Collect evidence

# %% [markdown]
# Importing Files

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c9afcee7-c5d1-4f82-baff-d3b36d452208" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9afcee7-c5d1-4f82-baff-d3b36d452208">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
centers = pd.read_csv("Costomer+OrderForm.csv")
centers.head(10)
# Out:
#   Phillippines   Indonesia       Malta       India
# 0   Error Free  Error Free   Defective  Error Free
# 1   Error Free  Error Free  Error Free   Defective
# 2   Error Free   Defective   Defective  Error Free
# 3   Error Free  Error Free  Error Free  Error Free
# 4   Error Free  Error Free   Defective  Error Free
# 5   Error Free  Error Free  Error Free  Error Free
# 6   Error Free   Defective  Error Free  Error Free
# 7   Error Free  Error Free  Error Free  Error Free
# 8   Error Free  Error Free  Error Free  Error Free
# 9   Error Free  Error Free  Error Free  Error Free

# %% [markdown]
# Applying Descriptive Statistics

# %%
centers.describe()
# Out:
#        Phillippines   Indonesia       Malta       India
# count           300         300         300         300
# unique            2           2           2           2
# top      Error Free  Error Free  Error Free  Error Free
# freq            271         267         269         280

# %% [markdown]
# Checking for Null Values

# %%
centers.isnull().sum()
# Out:
# Phillippines    0
# Indonesia       0
# Malta           0
# India           0
# dtype: int64

# %%
centers[centers.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Phillippines, Indonesia, Malta, India]
# Index: []

# %% [markdown]
# Checking the data type

# %%
centers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Phillippines  300 non-null    object
#  1   Indonesia     300 non-null    object
#  2   Malta         300 non-null    object
#  3   India         300 non-null    object
# dtypes: object(4)
# memory usage: 9.5+ KB

# %% [markdown]
# Checking value counts in data

# %%
print(centers['Phillippines'].value_counts(), '\n', centers['Indonesia'].value_counts(), '\n', centers['Malta'].value_counts(),'\n', centers['India'].value_counts())
# Out:
# Error Free    271
# Defective      29
# Name: Phillippines, dtype: int64
#  Error Free    267
# Defective      33
# Name: Indonesia, dtype: int64
#  Error Free    269
# Defective      31
# Name: Malta, dtype: int64
#  Error Free    280
# Defective      20
# Name: India, dtype: int64

# %% [markdown]
# Creating Contingency table

# %%
contingency_table = [[271,267,269,280],
                     [29,33,31,20]]
print(contingency_table)
# Out:
# [[271, 267, 269, 280], [29, 33, 31, 20]]

# %% [markdown]
# Calculating Expected Values for Observed Data

# %%
stat, p, df, exp = stats.chi2_contingency(contingency_table)
print("Statistics =", stat, '\n', 'P_Value = ', p, '\n', 'degrees of freedom = ',df, '\n', 'Expected Values = ', exp)
# Out:
# Statistics = 3.858960685820355
#  P_Value =  0.2771020991233135
#  degrees of freedom =  3
#  Expected Values =  [[271.75 271.75 271.75 271.75]
#  [ 28.25  28.25  28.25  28.25]]

# %% [markdown]
# Defining Expected values and Observed values

# %%
observed = np.array([271, 267, 269, 280, 29, 33, 31, 20])
expected = np.array([271.75, 271.75, 271.75, 271.75, 28.25, 28.25, 28.25, 28.25])

# %% [markdown]
# STEP 4
#
# Compare Evidences with Hypothesis using t-statistics

# %%
test_statistic, p_value = stats.chisquare(observed, expected, ddof = df)
print("Test Statistic = ", test_statistic, '\n', 'p_value = ', p_value)
# Out:
# Test Statistic =  3.858960685820355
#  p_value =  0.4254298144535761

# %% [markdown]
# Plotting the data

# %% [markdown]
# Compare p_value with 'α'(Significane Level)

# %% [markdown]
# If p_value is  ≠  ' α ' we failed to reject Null Hypothesis because of lack of evidence
#
# If p_value is = ' α ' we reject Null Hypothesis

# %% [markdown]
# Interpreting p-value

# %%
alpha = 0.05
print("Significance = %.3f, p=%.3f" % (alpha, p_value))
if p_value <= alpha:
  print("We reject Null Hypothesis there is a sinificance differnce between TAT of reports of the laboratories")
else:
  print("We fail to reject Null Hypothesis")
# Out:
# Significance = 0.050, p=0.425
# We fail to reject Null Hypothesis

# %% [markdown]
# We fail to reject Null Hypothesis because of lack of evidence.
